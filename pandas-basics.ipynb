# %%
import pandas as pd

# %%
s = pd.Series(["Mon","Tue","Wed","Thu","Fri"])
print(s)
# Out:
# 0    Mon
# 1    Tue
# 2    Wed
# 3    Thu
# 4    Fri
# dtype: object

# %%
data = [32,56,20]
label = ["Mon","Thu","Fri"]
s1 = pd.Series(data,label)
print(s1)
# Out:
# Mon    32
# Thu    56
# Fri    20
# dtype: int64

# %%
data = [20,34,56,11]
label = ["Mon","Tue","Wed","Fri"]
s2 = pd.Series(data,label)
print(s1+s2)
# Out:
# Fri    31.0
# Mon    52.0
# Thu     NaN
# Tue     NaN
# Wed     NaN
# dtype: float64

# %%
# Creating Dataframes using list
list1 = ["welcome","to","Data","science"]
label = ["w1","w2","w3","w4"]
df1 = pd.DataFrame(list1,label)
df1
# Out:
#           0
# w1  welcome
# w2       to
# w3     Data
# w4  science

# %%
# Creating Dataframes using Dictionary
index=["Emp1","Emp2","Emp3","Emp4","Emp5","Emp6","Emp7","Emp8","Emp9","Emp10"]
data = {'Name' : ["X","Y","Z","G","U","W","R","S","O","L"],
'Age' :[40,50,45,55,27,35,21,42,52,37],
'Address':["Bengaluru","Mumbai", "Chennai", "Hyderabad","China","Singapore","California","Tokyo","Malaysia","Houston"],
'Department':["HR",'IT Services', 'Products' ,'Strategy','IT Services','IT Services','IT Services','Products' ,'Strategy','IT Services'],
'BasicSal': [25000,45000,35000,50000,32000,28000,31000,41000,54000,60000]
}
df2 = pd.DataFrame(data,index)
df2
# Out:
#       Name  Age     Address   Department  BasicSal
# Emp1     X   40   Bengaluru           HR     25000
# Emp2     Y   50      Mumbai  IT Services     45000
# Emp3     Z   45     Chennai     Products     35000
# Emp4     G   55   Hyderabad     Strategy     50000
# Emp5     U   27       China  IT Services     32000
# Emp6     W   35   Singapore  IT Services     28000
# Emp7     R   21  California  IT Services     31000
# Emp8     S   42       Tokyo     Products     41000
# Emp9     O   52    Malaysia     Strategy     54000
# Emp10    L   37     Houston  IT Services     60000

# %%
df1 = pd.read_csv("C:/Users/Vignesh/Documents/Python-Workspace/datascience-intro/input/emp.csv")
df1.head(3)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  850297         Ms.     Shawna              W      Buck      F
# 1  304721         Mr.  Nathaniel              Z     Burke      M
# 2  412317        Drs.  Elisabeth              W    Foster      F
#
#                         E Mail  Father's Name Mother's Name  \
# 0        shawna.buck@gmail.com   Rosario Buck   Keisha Buck
# 1  nathaniel.burke@walmart.com  Derrick Burke  Phoebe Burke
# 2   elisabeth.foster@gmail.com   Irwin Foster  Janie Foster
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name   County  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas    Clark
# 1                 Pugh  ...  550-99-9897  231-765-6923       Irons     Lake
# 2              Delaney  ...  215-91-0004  270-749-4774   Lexington  Fayette
#
#         City State    Zip   Region  User Name         Password
# 0  Las Vegas    NV  89128     West     swbuck  ja8?k3BTF^]o@<&
# ...

# %%
df1.tail(4)
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail   Father's Name        Mother's Name  \
# 996          luke.turner@charter.net   Javier Turner        Nicole Turner
# 997           eva.holman@hotmail.com      Coy Holman         Haley Holman
# 998  maritza.christian@microsoft.com  Dion Christian  Stephanie Christian
# 999       phyllis.dudley@yahoo.co.in   Jarrod Dudley       Latisha Dudley
#
#     Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 996                Sykes  ...  056-02-8240  231-629-0498    Freeport
# 997                Boyle  ...  343-11-1935  209-912-6705     Turlock
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age in Yrs.             1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %%
df1.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# ...

# %%
df1.City
# Out:
# 0      Las Vegas
# 1          Irons
# 2      Lexington
# 3        Munster
# 4      Fairbanks
#          ...
# 995    Mukwonago
# 996     Freeport
# 997      Turlock
# 998     Stamford
# 999         Meno
# Name: City, Length: 1000, dtype: object

# %%
df1[["First Name","Last Name"]]
# Out:
#     First Name  Last Name
# 0       Shawna       Buck
# 1    Nathaniel      Burke
# 2    Elisabeth     Foster
# 3       Briana  Lancaster
# 4      Estella     Potter
# ..         ...        ...
# 995     Bonnie      Baker
# 996       Luke     Turner
# 997        Eva     Holman
# 998    Maritza  Christian
# 999    Phyllis     Dudley
#
# [1000 rows x 2 columns]

# %%
df1.rename(columns={"Age in Yrs.":"Age"},inplace=True)

# %%
df1[(df1.Age >= 35)]
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 7    159108        Mrs.     Shanna              U      Silva      F
# 8    330816         Ms.    Jasmine              J    Freeman      F
# 9    532002         Ms.      Madge              V    Sargent      F
# ..      ...         ...        ...            ...        ...    ...
# 984  199699       Prof.     George              W      Potts      M
# 989  873626        Mrs.      Sheri              A     Spears      F
# 990  247051         Ms.    Alberta              A       Page      F
# 997  359608        Hon.        Eva              S     Holman      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                          E Mail      Father's Name     Mother's Name  \
# 0         shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# ...

# %%
df1["HRA"] = df1.Salary * 0.3
df1.HRA
# Out:
# 0      35727.0
# 1      35397.3
# 2      48313.5
# 3      42784.8
# 4      40711.8
#         ...
# 995    21879.0
# 996    36584.7
# 997    24820.2
# 998    20056.2
# 999    31520.7
# Name: HRA, Length: 1000, dtype: float64

# %%
df2.loc[["Emp3","Emp5"]]
# Out:
#      Name  Age  Address   Department  BasicSal
# Emp3    Z   45  Chennai     Products     35000
# Emp5    U   27    China  IT Services     32000

# %%
# Groupby with aggregation
df2.groupby("Department").mean()[['Age','BasicSal']]
# Out:
#               Age  BasicSal
# Department
# HR           40.0   25000.0
# IT Services  34.0   39200.0
# Products     43.5   38000.0
# Strategy     53.5   52000.0

# %%
df_table = df2.pivot_table(index = 'Department',columns=['Address'],aggfunc = 'sum')
df_table
# Out:
#                   Age                                                      \
# Address     Bengaluru California Chennai China Houston Hyderabad Malaysia
# Department
# HR               40.0        NaN     NaN   NaN     NaN       NaN      NaN
# IT Services       NaN       21.0     NaN  27.0    37.0       NaN      NaN
# Products          NaN        NaN    45.0   NaN     NaN       NaN      NaN
# Strategy          NaN        NaN     NaN   NaN     NaN      55.0     52.0
#
#                                     BasicSal                               \
# Address     Mumbai Singapore Tokyo Bengaluru California  Chennai    China
# Department
# HR             NaN       NaN   NaN   25000.0        NaN      NaN      NaN
# IT Services   50.0      35.0   NaN       NaN    31000.0      NaN  32000.0
# Products       NaN       NaN  42.0       NaN        NaN  35000.0      NaN
# Strategy       NaN       NaN   NaN       NaN        NaN      NaN      NaN
#
#
# ...

# %%
df2.to_excel("C:/Users/Vignesh/Documents/Python-Workspace/datascience-intro/output/df2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6120/3351916599.py in <module>
# ----> 1 df2.to_excel("./output/df2.xlsx")
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2279             inf_rep=inf_rep,
#    2280         )
# -> 2281         formatter.write(
#    2282             excel_writer,
#    2283             sheet_name=sheet_name,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     832             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
# ...
